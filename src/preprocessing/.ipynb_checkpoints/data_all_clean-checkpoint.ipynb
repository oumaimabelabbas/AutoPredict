# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_scrapped = pd.read_csv('../../data/scrapped/avito_scraper.csv',encoding='latin1')

# %%
data_scrapped.head(20)
# Out:
#     id                                               Lien            Ville  \
# 0    0  https://www.avito.ma/fr/massira_2/voitures/FIA...           Temara
# 1    1  https://www.avito.ma/fr/temara/voitures/Dacia_...           Temara
# 2    2  https://www.avito.ma/fr/casablanca/voitures/Da...       Casablanca
# 3    3  https://www.avito.ma/fr/casablanca/voitures/to...       Casablanca
# 4    4  https://www.avito.ma/fr/dakhla/voitures/Toyota...           Dakhla
# 5    5  https://www.avito.ma/fr/khouribga/voitures/Tig...        Khouribga
# 6    6  https://www.avito.ma/fr/autre_secteur/voitures...           Meknès
# 7    7  https://www.avito.ma/fr/casablanca/voitures/Re...       Casablanca
# 8    8  https://www.avito.ma/fr/mohammedia/voitures/Pe...       Mohammedia
# 9    9  https://www.avito.ma/fr/fquih_ben_saleh/voitur...  Fquih Ben Saleh
# 10  10  https://www.avito.ma/fr/zitoune/voitures/Dacia...           Meknès
# 11  11  https://www.avito.ma/fr/f%C3%A8s/voitures/kong...              Fès
# 12  12  https://www.avito.ma/fr/ait_Melloul/voitures/F...      Ait Melloul
# 13  13  https://www.avito.ma/fr/t%C3%A9touan/voitures/...          Tétouan
# 14  14  https://www.avito.ma/fr/zemmouri/voitures/Citr...           Tanger
# 15  15  https://www.avito.ma/fr/ain_sebaa/voitures/Log...       Casablanca
# 16  16  https://www.avito.ma/fr/rabat/voitures/Audi_A3...            Rabat
# 17  17  https://www.avito.ma/fr/rabat/voitures/FORD_FO...            Rabat
# 18  18  https://www.avito.ma/fr/daoudiate/voitures/Peu...        Marrakech
# 19  19  https://www.avito.ma/fr/t%C3%A9touan/voitures/...          Tétouan
#
#          Secteur         Marque             Modèle  Année-Modèle  \
# 0      Massira 2           Fiat              Punto          2007
# 1   non spécifié          Dacia         Dokker Van          2013
# 2   non spécifié          Dacia             Dokker          2014
# 3   non spécifié     Volkswagen            Touareg          2005
# 4   non spécifié         Toyota              Prado          2007
# 5   non spécifié     Volkswagen             Tiguan          2014
# 6   non spécifié        Peugeot                308          2009
# 7   non spécifié        Renault               Clio          2014
# 8   non spécifié        Peugeot                208          2021
# 9   non spécifié     Volkswagen             GOLF 7          2013
# 10       Zitoune          Dacia             Dokker          2016
# 11  non spécifié        Renault             Kangoo          2008
# 12  non spécifié           Ford               Kuga          2016
# 13  non spécifié     Land Rover  Range Rover Sport          2018
# 14      Zemmouri        Citroen           Berlingo          2015
# 15     Aïn Sebaâ          Dacia          Logan Mcv          2017
# 16  non spécifié           Audi                 A3          2018
# 17  non spécifié           Ford              Focus          2014
# 18     Daoudiate        Peugeot                301          2018
# 19  non spécifié  Mercedes-Benz                220          1998
#
#           Kilométrage Type de carburant  Puissance fiscale  ...  \
# 0   200 000 - 249 999            Diesel                  5  ...
# 1   400 000 - 449 999            Diesel                  6  ...
# 2   160 000 - 169 999            Diesel                  6  ...
# 3           0 - 4 999            Diesel                 10  ...
# 4   200 000 - 249 999            Diesel                 12  ...
# 5   180 000 - 189 999            Diesel                  8  ...
# 6   200 000 - 249 999            Diesel                  6  ...
# 7     75 000 - 79 999            Diesel                  6  ...
# 8     10 000 - 14 999            Diesel                  6  ...
# 9   120 000 - 129 999            Diesel                  8  ...
# 10  110 000 - 119 999            Diesel                  6  ...
# 11  160 000 - 169 999            Diesel                  6  ...
# 12  200 000 - 249 999            Diesel                  8  ...
# 13    35 000 - 39 999            Diesel                 12  ...
# 14    10 000 - 14 999           Essence                  6  ...
# 15          0 - 4 999            Diesel                  5  ...
# 16    90 000 - 94 999            Diesel                  6  ...
# 17  190 000 - 199 999            Diesel                  6  ...
# 18    50 000 - 54 999            Diesel                  6  ...
# 19  300 000 - 349 999            Diesel                  9  ...
#
#    Caméra de recul Vitres électriques    ABS    ESP Régulateur de vitesse  \
# 0            False              False   True  False                 False
# 1            False              False  False  False                 False
# 2            False              False  False  False                 False
# 3            False              False  False  False                 False
# 4            False              False   True  False                 False
# 5            False              False   True   True                 False
# 6            False              False   True   True                 False
# 7            False              False   True   True                 False
# 8            False              False   True   True                 False
# 9            False              False   True   True                 False
# 10           False              False  False  False                 False
# 11           False              False  False  False                 False
# 12           False              False   True   True                 False
# 13           False              False   True   True                 False
# 14           False              False  False  False                 False
# 15           False              False   True  False                 False
# 16           False              False   True   True                 False
# 17           False              False   True  False                 False
# 18           False              False  False  False                 False
# 19           False              False   True   True                 False
#
#     Limiteur de vitesse  CD/MP3/Bluetooth  Ordinateur de bord  \
# 0                 False              True               False
# 1                 False             False               False
# 2                 False             False               False
# 3                 False             False               False
# 4                 False              True               False
# 5                 False              True               False
# 6                 False              True               False
# 7                 False              True               False
# 8                 False              True               False
# 9                 False              True               False
# 10                False             False               False
# 11                False             False               False
# 12                False              True               False
# 13                False              True               False
# 14                False             False               False
# 15                False              True               False
# 16                False              True               False
# 17                False              True               False
# 18                False             False               False
# 19                False              True               False
#
#     Verrouillage centralisé à distance    Prix
# 0                                False   60000
# 1                                False   70000
# 2                                False   90000
# 3                                False   90000
# 4                                False   97000
# 5                                False  255000
# 6                                False   85000
# 7                                False   93000
# 8                                False  164000
# 9                                False  198000
# 10                               False  114000
# 11                               False   70000
# 12                               False  180000
# 13                               False  780000
# 14                               False  105000
# 15                               False   98000
# 16                               False  340000
# 17                               False  128000
# 18                               False  107000
# 19                               False   87000
#
# [20 rows x 32 columns]

# %%
data_scrapped.shape
# Out:
# (24776, 32)

# %%
data_scrapped.columns.to_list()
# Out:
# ['id',
#  'Lien',
#  'Ville',
#  'Secteur',
#  'Marque',
#  'Modèle',
#  'Année-Modèle',
#  'Kilométrage',
#  'Type de carburant',
#  'Puissance fiscale',
#  'Boite de vitesses',
#  'Nombre de portes',
#  'Origine',
#  'Première main',
#  'État',
#  'Jantes aluminium',
#  'Airbags',
#  'Climatisation',
#  'Système de navigation/GPS',
#  'Toit ouvrant',
#  'Sièges cuir',
#  'Radar de recul',
#  'Caméra de recul',
#  'Vitres électriques',
#  'ABS',
#  'ESP',
#  'Régulateur de vitesse',
#  'Limiteur de vitesse',
#  'CD/MP3/Bluetooth',
#  'Ordinateur de bord',
#  'Verrouillage centralisé à distance',
#  'Prix']

# %%
#see the duplicates
data_scrapped.duplicated().sum()
# Out:
# 0

# %%
#remove the column Date_pub
data_scrapped = data_scrapped.drop(columns=['id',
 'Lien','Secteur','État',
 'Jantes aluminium',
 'Airbags',
 'Climatisation',
 'Système de navigation/GPS',
 'Toit ouvrant',
 'Sièges cuir',
 'Radar de recul',
 'Caméra de recul',
 'Vitres électriques',
 'ABS',
 'ESP',
 'Régulateur de vitesse',
 'Limiteur de vitesse',
 'CD/MP3/Bluetooth',
 'Ordinateur de bord',
 'Verrouillage centralisé à distance'])

# %% [markdown]
# # Conversion en Numérique

# %%
data_scrapped['Année-Modèle'] = pd.to_numeric(data_scrapped['Année-Modèle'], errors='coerce').fillna(0).astype(int)

# %%
data_scrapped['Nombre de portes'] = pd.to_numeric(data_scrapped['Nombre de portes'], errors='coerce')

# %%
#remove the CV in the column Puissange fiscale  
data_scrapped['Puissance fiscale']=data_scrapped['Puissance fiscale'].astype(str).str.split().apply(lambda x : x[0] if len(x[0])>0 else None)
#convert to the column to num
data_scrapped['Puissance fiscale'] = pd.to_numeric(data_scrapped['Puissance fiscale'], errors='coerce')

# %%
#remove DH from price
data_scrapped['Prix']=data_scrapped['Prix'].astype(str).str.replace('DH','').str.replace(r'\s+','', regex=True)
#convert to the column to num
data_scrapped['Prix'] = pd.to_numeric(data_scrapped['Prix'], errors='coerce')

# %%
#convert the column Kilometrage to a single value
data_scrapped['Kilométrage'] = data_scrapped['Kilométrage'].astype(str).str.replace(' ','').str.split('-').apply(lambda x :(int(x[0])+int(x[1]))/2 if len(x)==2 else None)

# %%
#name of columns
data_scrapped.columns.to_list()
# Out:
# ['Ville',
#  'Marque',
#  'Modèle',
#  'Année-Modèle',
#  'Kilométrage',
#  'Type de carburant',
#  'Puissance fiscale',
#  'Boite de vitesses',
#  'Nombre de portes',
#  'Origine',
#  'Première main',
#  'Prix']

# %%
#unique values of type de carburant
data_scrapped['Type de carburant'].unique()
# Out:
# array(['Diesel', 'Essence', 'Hybride', 'Electrique'], dtype=object)

# %%
#see number of the rows where price <20000
data_scrapped[data_scrapped['Prix']<20000]
# Out:
# Empty DataFrame
# Columns: [Ville, Marque, Modèle, Année-Modèle, Kilométrage, Type de carburant, Puissance fiscale, Boite de vitesses, Nombre de portes, Origine, Première main, Prix]
# Index: []

# %%
data_scrapped = data_scrapped.drop(
    data_scrapped[
        (data_scrapped['Origine'] == 'Pas encore dédouanée') | 
        (data_scrapped['Origine'] == 'non spécifié')
    ].index
)

# %%
#convert the column Puissance 
data_scrapped['Puissance fiscale']= data_scrapped['Puissance fiscale'].astype(int)

# %%
data_scrapped['Origine'].unique()
# Out:
# array(['WW au Maroc', 'Dédouanée', 'Importée neuve'], dtype=object)

# %%
data_scrapped['Ville'].unique()
# Out:
# array(['Temara', 'Casablanca', 'Dakhla', 'Khouribga', 'Meknès',
#        'Mohammedia', 'Fquih Ben Saleh', 'Ait Melloul', 'Tétouan',
#        'Tanger', 'Rabat', 'Marrakech', 'Taounate', 'El Jadida', 'Kénitra',
#        'Sidi Bou Othmane', 'Sidi Slimane', 'Khénifra', 'Fès', 'Agadir',
#        'Salé', 'Tifelt', 'Guercif', 'Jorf El Melha', 'Oujda', 'Zagora',
#        'Ouarzazate', 'Imouzzer-Kendar', 'Safi', 'El Kelâa des Sraghna',
#        'Béni Mellal', 'Laâyoune', 'Al Hoceïma', 'Tahannaout', 'Taza',
#        'Khemisset', 'Essaouira', 'Azrou', 'Oualidia', 'Bouznika',
#        'Boulemane', 'Berkane', 'Laattaouia', 'Nador', 'Settat',
#        'El Hajeb', 'Sidi Yahya', 'Ain Aouda', 'Deroua', 'Berrechid',
#        'Souk Sebt Ouled Nemma', 'Karia Ba Mohamed', 'Errachidia',
#        'Ben Guerir', 'Benslimane', 'Sidi Kacem', 'Tinejdad', 'Chichaoua',
#        'Dcheïra El Jihadia', 'Mechra Bel Ksiri', 'Houara Oulad Raho',
#        'Ouazzane', 'Méchouar Fès Jdid', 'Rommani', 'Nouaceur',
#        'Ouled Teïma', 'Souk El Arbaa', 'Midelt', 'Taroudant',
#        'Sidi Rahal', 'Larache', 'Talmest', 'Youssoufia', 'Guelmim',
#        'Skhirat', 'Biougra', 'Ksar el-Kebir', 'Ifrane', 'Bouskoura',
#        'Sidi Ifni', 'Sefrou', 'Sebt Gzoula', 'Oued Laou', 'El Gara',
#        'Sidi Allal El Bahraoui', 'Kasba Tadla', 'Al Oioun Sidi Mellouk',
#        'Echemmaia', 'Oued Zem', 'Thar Es-Souk', 'Ain Taoujdate',
#        'Ksar es-Seghir', 'Zaouïat Cheikh', 'Ain Harrouda',
#        'Aarab Sebbah Gheris', 'Tit Mellil', 'Tiznit', 'Agadir Melloul',
#        'Errahma', 'Chefchaouen', 'Missour', 'Belfaa', 'Taourirt',
#        'Sidi Bennour', 'Laaouama', 'Asilah', 'Moulay Driss Zerhoun',
#        'Skhour Rhamna', 'Bouizakarne', 'Tamesna', 'Tahla',
#        'Sidi Rahal Chatai', 'Boujdour', 'Azilal', 'Tan-Tan', 'Inzegan',
#        'Mdiq', 'Er-Rich', 'Had Soualem', 'Ben Ahmed', 'Azemmour',
#        'Bouarfa', 'Sidi Yahya El Gharb', 'Tinghir', 'Sidi Boukhalkhal',
#        'Béni Yakhlef', 'Al Aaroui', 'Afourar', 'Zoumi', 'Ratba', 'Tata',
#        'El Borouj', 'Demnate', 'Sidi Slimane Echcharraa', 'Martil',
#        'Assa zag', 'Imouzzer', 'Jamaat Shaim', 'Targuist', 'Ait Ourir',
#        'Bejaad', 'Bir Jdid', 'Brachoua', 'Driouch', 'Mediouna',
#        'Lagfifat', 'Tissa', 'Bab Berred', 'Sidi Yahya Zaer',
#        "Aghbalou N'kerdous", 'Bab Taza', 'Zaïo', 'Outat El Haj',
#        'Ain Attig', 'Skoura Ahl El Oust', 'Dar Bouazza', 'Ourika',
#        'Ribat el Kheir', "Oulad Said L'oued", 'Mallalienne', 'Es-Semara',
#        'Zemamra', 'Imintanoute', 'Ouaouizeght', 'Ain Tizgha', 'Ouaoumana',
#        'Lbir Jdid', 'Oued Amlil', 'Rissani', 'Issen',
#        'Souk Tlet El Gharb', 'Boughriba', 'Taliouine', 'Arbaoua',
#        'Ouled Ayad'], dtype=object)

# %%
#number of nan values in each column
data_scrapped.isna().sum()
# Out:
# Ville                   0
# Marque                  0
# Modèle                  0
# Année-Modèle            0
# Kilométrage             0
# Type de carburant       0
# Puissance fiscale       0
# Boite de vitesses       0
# Nombre de portes     1006
# Origine                 0
# Première main           0
# Prix                    0
# dtype: int64

# %%
# Liste des modèles ayant 3 portes
models_with_3_doors = data_scrapped[data_scrapped['Nombre de portes']==3]['Modèle'].unique()

# Remplir les valeurs manquantes pour ces modèles
data_scrapped.loc[
    (data_scrapped['Modèle'].isin(models_with_3_doors)) & 
    (data_scrapped['Nombre de portes'].isna()),
    'Nombre de portes'
] = 3

# %%
# Liste des modèles ayant 3 portes
models_with_5_doors = data_scrapped[data_scrapped['Nombre de portes']==5]['Modèle'].unique()

# Remplir les valeurs manquantes pour ces modèles
data_scrapped.loc[
    (data_scrapped['Modèle'].isin(models_with_5_doors)) & 
    (data_scrapped['Nombre de portes'].isna()),
    'Nombre de portes'
] = 5

# %%
#remove the rows where theres left none values in nombre de portes
data_scrapped=data_scrapped.dropna(subset=['Nombre de portes'])

# %%
#remove lines where Premiere main = non spécifié
data_scrapped = data_scrapped[data_scrapped['Première main'] != 'non spécifié']

# %%
data_scrapped = data_scrapped[data_scrapped['Boite de vitesses'] != 'non spécifié']

# %%
data_scrapped.shape
# Out:
# (17228, 12)

# %%
data_scrapped.duplicated().sum()
# Out:
# 11610

# %%
data_scrapped = data_scrapped.drop_duplicates()

# %%
data_scrapped.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # concat our data with other clean data

# %%
data_scrapped1=  pd.read_csv('../../data/scrapped/voitures_clean2.csv')
data_scrapped2 = pd.read_csv('../../data/scrapped/voitures_clean3.csv')

# %%
data_scrapped = pd.concat([data_scrapped, data_scrapped1,data_scrapped2], ignore_index=True, sort=False)

# %%
data_scrapped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66650 entries, 0 to 66649
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ville              66650 non-null  object
#  1   Marque             66650 non-null  object
#  2   Modèle             66650 non-null  object
#  3   Année-Modèle       66650 non-null  int64
#  4   Kilométrage        66164 non-null  float64
#  5   Type de carburant  66650 non-null  object
#  6   Puissance fiscale  66650 non-null  float64
#  7   Boite de vitesses  66650 non-null  object
#  8   Nombre de portes   66650 non-null  float64
#  9   Origine            66650 non-null  object
#  10  Première main      66650 non-null  object
#  11  Prix               66650 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 6.1+ MB

# %%
data_scrapped.duplicated().sum()
# Out:
# 9496

# %%
data_scrapped = data_scrapped.drop_duplicates().reset_index(drop=True)

# %%
data_scrapped.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Keep the cities with frequency > 1%

# %%
#keep the most used cities after concat two clean data
cities = data_scrapped["Ville"].value_counts(normalize=True)
rare = cities[cities < 0.01].index

data_scrapped.loc[:, 'Ville_grouped'] = data_scrapped['Ville'].replace(rare, 'Autres')

# %%
#visualise the cities left
data_scrapped['Ville_grouped'].value_counts()
# Out:
# Ville_grouped
# Casablanca     14641
# Autres         10449
# Tanger          3930
# Marrakech       3925
# Rabat           3919
# Agadir          3141
# Fès             3088
# Meknès          2200
# Salé            2110
# Kénitra         2019
# El Jadida       1493
# Temara          1315
# Tétouan         1118
# Mohammedia      1029
# Oujda            871
# Nador            693
# Béni Mellal      625
# Safi             588
# Name: count, dtype: int64

# %%
data_scrapped.shape
# Out:
# (57154, 13)

# %%
#create a new feature (age_vehicule)
data_scrapped['Age_vehicule'] = 2025 - data_scrapped['Année-Modèle']

# %% [markdown]
# # Visualise scatterplot to see the relationship of age_vehicule avec le prix

# %%
# Create a scatter plot of the data. To change the markers to red "x",
# we used the 'marker' and 'c' parameters
plt.scatter(data_scrapped['Age_vehicule'], data_scrapped['Prix'], marker='x', c='r') 

# Set the title
plt.title(" Price cars vs Age cars")
# Set the y-axis label
plt.ylabel('Price car')
# Set the x-axis label
plt.xlabel('Age car')
plt.show()

# %% [markdown]
# # Remove the outliers

# %%
#show the boxplot for Prix
sns.boxplot(x=data_scrapped['Kilométrage'])
plt.title("Boxplots du Kilométrage avant suppréssion des outliers")

plt.show()

# %%
#show the boxplot for Prix
sns.boxplot(x=data_scrapped['Prix'])
plt.title("Boxplots du Prix avant suppréssion des outliers")

plt.show()

# %%
#show how much outliers we have in Kilometrage
Q1 = data_scrapped['Kilométrage'].quantile(0.25)
Q3 = data_scrapped['Kilométrage'].quantile(0.75)
IQR = Q3 - Q1
lower_km = Q1 - 1.5 * IQR
upper_km = Q3 + 1.5 * IQR
data_scrapped[(data_scrapped['Kilométrage'] < lower_km) | (data_scrapped['Kilométrage'] > upper_km)]['Kilométrage'].shape
# Out:
# (781,)

# %%
#show how much outliers we have in Prix

Q1 = data_scrapped['Prix'].quantile(0.25)
Q3 = data_scrapped['Prix'].quantile(0.75)
IQR = Q3 - Q1
lower_prix = Q1 - 1.5 * IQR
upper_prix = Q3 + 1.5 * IQR
data_scrapped[(data_scrapped['Prix'] < lower_prix) | (data_scrapped['Prix'] > upper_prix)]['Prix'].shape
# Out:
# (3597,)

# %%
#drop the outliers
data_scrapped = data_scrapped[
    (data_scrapped['Prix'] >= lower_prix) & (data_scrapped['Prix'] <= upper_prix) &
    (data_scrapped['Kilométrage'] >= lower_km) & (data_scrapped['Kilométrage'] <= upper_km)
]

# %%
data_scrapped= data_scrapped.reset_index(drop=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# On met les deux colonnes dans un DataFrame "long" pour seaborn
df_long = data_scrapped[['Kilométrage', 'Prix']].melt(var_name='Variable', value_name='Valeur')

sns.boxplot(x='Variable', y='Valeur', data=df_long)
plt.title("Boxplots  Kilométrage et du Prix après suppréssion des outliers")
plt.show()

# %%
data_scrapped.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Save our file cleaned

# %%
#save the file
data_scrapped.to_csv('../../data/scrapped/voitures_clean.csv',index=False)

# %%
data_scrapped.shape
# Out:
# (52351, 14)

# %%
data_scrapped['Ville_grouped'].unique()
# Out:
# array(['Temara', 'Casablanca', 'Autres', 'Meknès', 'Mohammedia', 'Tanger',
#        'Rabat', 'Marrakech', 'Tétouan', 'El Jadida', 'Kénitra', 'Fès',
#        'Agadir', 'Salé', 'Oujda', 'Safi', 'Béni Mellal', 'Nador'],
#       dtype=object)
